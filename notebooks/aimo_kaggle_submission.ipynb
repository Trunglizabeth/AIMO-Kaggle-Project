# %% [markdown]
# # AIMO Kaggle Submission Notebook
#
# This notebook demonstrates how to generate a Kaggle-style submission using the AIMO solver pipeline. It shows how to verify offline packages, install dependencies, and run the submission generator in a Kaggle environment.

# %%
import os
import sys
from pathlib import Path

# Add repository root to sys.path for local imports
repo_root = Path('..').resolve()
sys.path.insert(0, str(repo_root))

# %% [markdown]
# ## Verify offline wheel packages
#
# If you are running inside Kaggle, set `dataset_dir` to the mounted dataset containing wheel files. Otherwise skip this step if dependencies are already available.

# %%
dataset_dir = Path('/kaggle/input/aimo-offline-packages')
print('Dataset path:', dataset_dir)

# Uncomment the following line inside Kaggle if the dataset exists",
]},{
:
,
:{},
:[
,
,
]},{
:
,
:null,
:{},
:[],
:[
,
]},{
:
,
:{},
:[
,
,
]},{
:
,
:null,
:{},
:[],
:[
]}],
:{
:{
:
3
,
:
,
:
},
:{
:
}},
:4,
:5}
